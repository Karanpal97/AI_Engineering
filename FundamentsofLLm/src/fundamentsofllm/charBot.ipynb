# %%
def stateless_chatgpt(prompt: str)->str:
    from dotenv import load_dotenv
    from openai import OpenAI

    import os

    load_dotenv()


    client=OpenAI(api_key=os.getenv("api_key"),base_url=os.getenv("base_url"))
    response=client.chat.completions.create(
                model="openai/gpt-oss-120b",
                messages=[
                    {"role":"user","content":prompt}
                ]
            )
    reply=response.choices[0].message.content
    print(f"\n TaskBuddy: {reply}")



stateless_chatgpt("who is  education minister of india")

stateless_chatgpt("tell me more about him")
# Out:
#  TaskBuddy: As of August 2026, the Union Minister of Education (often referred to as the “Education Minister”) of India is **Dharmendra Pradhan**. He has held the portfolio since July 2021, when he was appointed in Prime Minister Narendra Modi’s cabinet, and he continued in the role after the 2024 general election and the subsequent cabinet reshuffle.
#
# *(If there have been any very recent changes after August 2026, you may want to double‑check the latest government press releases or the Ministry of Education’s official website for the most up‑to‑date information.)*
#
#  TaskBuddy: I’m not sure which person you’d like to know more about. Could you let me know who “him” refers to? That way I can provide the information you’re looking for.
